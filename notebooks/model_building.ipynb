# %% [markdown]
# # Part 4: Building a model

# %% [markdown]
# ## Part 4: Building a Model
# Build a regression model using Python’s statsmodels module that demonstrates a relationship between the number of bikes in a particular location and the characteristics of the POIs in that location.
# Interpret results. Expand on the model output, and derive insights from your model.
# Stretch: can you think of a way to turn the above regression problem into a classification one? Without coding, can you sketch out how you would cast the problem specifically, and lay out your approaches?
# Complete the model_building.ipynb notebook to demonstrate how you executed the tasks above.

# %% [markdown]
# Build a regression model.

# %%
# imports
import requests
from IPython.display import JSON 
import pandas as pd
import os
import requests
import json
import matplotlib

# %%
import statsmodels.api as sm

# %% [markdown]
# ## Foursquare Data

# %%
# bring in data from part 3 
mtl_results_fsq = pd.read_csv('../data/mtl_results_fsq.csv')
mtl_results_fsq
# Out:
#      latitude  longitude  restaurant count  num stalls
# 0   45.617500 -73.606011                 6          11
# 1   45.516926 -73.564257                50          14
# 2   45.541549 -73.565012                41          11
# 3   45.506176 -73.711186                 9          19
# 4   45.512994 -73.682498                41          19
# 5   45.514734 -73.691449                42          15
# 6   45.522341 -73.721679                20          15
# 7   45.566869 -73.641017                10          15
# 8   45.548136 -73.624340                50          13
# 9   45.447916 -73.583819                 6          19
# 10  45.512933 -73.633890                15          23
# 11  45.429471 -73.593099                 4          23
# 12  45.523319 -73.520127                23          29
# 13  45.533682 -73.515261                34          15
# 14  45.537226 -73.495067                15          18
# 15  45.528410 -73.517166                27          10
# 16  45.467140 -73.542590                11          29
# 17  45.553219 -73.539782                48          22
# 18  45.564937 -73.555591                 7          23
# 19  45.505721 -73.629459                49          27
# 20  45.510163 -73.556637                50          32
# 21  45.526890 -73.572640                50          29
# 22  45.651406 -73.500413                16          15
# 23  45.606235 -73.628784                13          18
# 24  45.507144 -73.555119                50          15
# 25  45.506373 -73.524577                 6          19
# 26  45.521565 -73.535332                 3          21
# 27  45.457509 -73.639485                19          24
# 28  45.472561 -73.569989                50          17
# 29  45.605902 -73.534369                13          13
# 30  45.439145 -73.591737                 0          15
# 31  45.471882 -73.640022                28          22
# 32  45.553400 -73.662255                35          13
# 33  45.574147 -73.574621                30          21
# 34  45.597221 -73.562790                48          19
# 35  45.559842 -73.615447                21          33
# 36  45.554947 -73.555295                10          21
# 37  45.568330 -73.566663                 4          22
# 38  45.436568 -73.708370                 0          19
# 39  45.438056 -73.672739                19          19
# 40  45.456823 -73.546804                 2          14
# 41  45.489186 -73.571900                50          20
# 42  45.522525 -73.691440                18          22
# 43  45.508979 -73.698564                13          25
# 44  45.504038 -73.704443                13          23
# 45  45.490494 -73.638522                43          15
# 46  45.531944 -73.713605                18          12
# 47  45.480495 -73.577827                50          24
# 48  45.491226 -73.587630                50          22
# 49  45.593985 -73.637672                13          21

# %%
X = mtl_results_fsq['restaurant count']
y = pd.Series(mtl_results_fsq['num stalls'])

# %%
# check y and x values
X
# Out:
# 0      6
# 1     50
# 2     41
# 3      9
# 4     41
# 5     42
# 6     20
# 7     10
# 8     50
# 9      6
# 10    15
# 11     4
# 12    23
# 13    34
# 14    15
# 15    27
# 16    11
# 17    48
# 18     7
# 19    49
# 20    50
# 21    50
# 22    16
# 23    13
# 24    50
# 25     6
# 26     3
# 27    19
# 28    50
# 29    13
# 30     0
# 31    28
# 32    35
# 33    30
# 34    48
# 35    21
# 36    10
# 37     4
# 38     0
# 39    19
# 40     2
# 41    50
# 42    18
# 43    13
# 44    13
# 45    43
# 46    18
# 47    50
# 48    50
# 49    13
# Name: restaurant count, dtype: int64

# %%
y
# Out:
# 0     11
# 1     14
# 2     11
# 3     19
# 4     19
# 5     15
# 6     15
# 7     15
# 8     13
# 9     19
# 10    23
# 11    23
# 12    29
# 13    15
# 14    18
# 15    10
# 16    29
# 17    22
# 18    23
# 19    27
# 20    32
# 21    29
# 22    15
# 23    18
# 24    15
# 25    19
# 26    21
# 27    24
# 28    17
# 29    13
# 30    15
# 31    22
# 32    13
# 33    21
# 34    19
# 35    33
# 36    21
# 37    22
# 38    19
# 39    19
# 40    14
# 41    20
# 42    22
# 43    25
# 44    23
# 45    15
# 46    12
# 47    24
# 48    22
# 49    21
# Name: num stalls, dtype: int64

# %% [markdown]
# Provide model output and an interpretation of the results.

# %%
# make a regresssion to predict the num of restaurants based on the num of stalls available 
x = sm.add_constant(X) # adding a constant
lin_reg = sm.OLS(y,x)
print('x type:', type(x))
# Out:
# x type: <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Model Analysis - Foursquare:
#
# * very high p-value of 0.818 indicates there is not a statistically significant relationship between the the number of restaurants to effectively predict the # of stalls available
# * a negative adjusted r-square value of -0.020 indicates that this model does not effecitively explain any patterns in the data.
# * Despite finding the original bug causing only 8 data points in previous analysis, It's clear that even with additional data points, there is no clear relationship between the count of restaurants and the number of city bikes stalls (See Scatter plots created in Joining Data).

# %%
model = lin_reg.fit()
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             num stalls   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.020
# Method:                 Least Squares   F-statistic:                   0.05346
# Date:                Fri, 21 Apr 2023   Prob (F-statistic):              0.818
# Time:                        16:08:50   Log-Likelihood:                -155.59
# No. Observations:                  50   AIC:                             315.2
# Df Residuals:                      48   BIC:                             319.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               19.2420      1.364     14.107      0.000      16.500      21.984
# restaurant count     0.0104      0.045      0.231      0.818      -0.080       0.101
# ==============================================================================
# Omnibus:                        1.790   Durbin-Watson:                   1.418
# Prob(Omnibus):                  0.409   Jarque-Bera (JB):                1.688
# Skew:                           0.426   Prob(JB):                        0.430
# Kurtosis:                       2.711   Cond. No.                         52.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Yelp Data

# %%
mtl_results_yelp = pd.read_csv('../data/mtl_results_yelp.csv')
mtl_results_yelp
# Out:
#      latitude  longitude  restaurant count  num stalls
# 0   45.617500 -73.606011                18          11
# 1   45.516926 -73.564257               602          14
# 2   45.541549 -73.565012               100          11
# 3   45.506176 -73.711186                29          19
# 4   45.512994 -73.682498                89          19
# 5   45.514734 -73.691449                89          15
# 6   45.522341 -73.721679                27          15
# 7   45.566869 -73.641017                31          15
# 8   45.548136 -73.624340               150          13
# 9   45.447916 -73.583819                31          19
# 10  45.512933 -73.633890                23          23
# 11  45.429471 -73.593099                 8          23
# 12  45.523319 -73.520127                32          29
# 13  45.533682 -73.515261                58          15
# 14  45.537226 -73.495067                29          18
# 15  45.528410 -73.517166                50          10
# 16  45.467140 -73.542590                18          29
# 17  45.553219 -73.539782                82          22
# 18  45.564937 -73.555591                12          23
# 19  45.505721 -73.629459                84          27
# 20  45.510163 -73.556637               711          32
# 21  45.526890 -73.572640               360          29
# 22  45.651406 -73.500413                28          15
# 23  45.606235 -73.628784                27          18
# 24  45.507144 -73.555119               705          15
# 25  45.506373 -73.524577                14          19
# 26  45.521565 -73.535332                 6          21
# 27  45.457509 -73.639485                17          24
# 28  45.472561 -73.569989               108          17
# 29  45.605902 -73.534369                20          13
# 30  45.439145 -73.591737                 4          15
# 31  45.471882 -73.640022                33          22
# 32  45.553400 -73.662255                70          13
# 33  45.574147 -73.574621                41          21
# 34  45.597221 -73.562790                61          19
# 35  45.559842 -73.615447                40          33
# 36  45.554947 -73.555295                35          21
# 37  45.568330 -73.566663                16          22
# 38  45.436568 -73.708370                 0          19
# 39  45.438056 -73.672739                29          19
# 40  45.456823 -73.546804                 4          14
# 41  45.489186 -73.571900               452          20
# 42  45.522525 -73.691440                52          22
# 43  45.508979 -73.698564                22          25
# 44  45.504038 -73.704443                39          23
# 45  45.490494 -73.638522               141          15
# 46  45.531944 -73.713605                23          12
# 47  45.480495 -73.577827               200          24
# 48  45.491226 -73.587630               386          22
# 49  45.593985 -73.637672                36          21

# %%
X = mtl_results_yelp['restaurant count']
y = pd.Series(mtl_results_yelp['num stalls'])

# %%
# check y and x values
X
# Out:
# 0      18
# 1     602
# 2     100
# 3      29
# 4      89
# 5      89
# 6      27
# 7      31
# 8     150
# 9      31
# 10     23
# 11      8
# 12     32
# 13     58
# 14     29
# 15     50
# 16     18
# 17     82
# 18     12
# 19     84
# 20    711
# 21    360
# 22     28
# 23     27
# 24    705
# 25     14
# 26      6
# 27     17
# 28    108
# 29     20
# 30      4
# 31     33
# 32     70
# 33     41
# 34     61
# 35     40
# 36     35
# 37     16
# 38      0
# 39     29
# 40      4
# 41    452
# 42     52
# 43     22
# 44     39
# 45    141
# 46     23
# 47    200
# 48    386
# 49     36
# Name: restaurant count, dtype: int64

# %%
y
# Out:
# 0     11
# 1     14
# 2     11
# 3     19
# 4     19
# 5     15
# 6     15
# 7     15
# 8     13
# 9     19
# 10    23
# 11    23
# 12    29
# 13    15
# 14    18
# 15    10
# 16    29
# 17    22
# 18    23
# 19    27
# 20    32
# 21    29
# 22    15
# 23    18
# 24    15
# 25    19
# 26    21
# 27    24
# 28    17
# 29    13
# 30    15
# 31    22
# 32    13
# 33    21
# 34    19
# 35    33
# 36    21
# 37    22
# 38    19
# 39    19
# 40    14
# 41    20
# 42    22
# 43    25
# 44    23
# 45    15
# 46    12
# 47    24
# 48    22
# 49    21
# Name: num stalls, dtype: int64

# %%
# make a regresssion to predict the num of restaurants based on the num of stalls available 
x = sm.add_constant(X) # adding a constant
lin_reg = sm.OLS(y,x)
print('x type:', type(x))
# Out:
# x type: <class 'pandas.core.frame.DataFrame'>

# %%
model = lin_reg.fit()
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             num stalls   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.6206
# Date:                Fri, 21 Apr 2023   Prob (F-statistic):              0.435
# Time:                        16:10:57   Log-Likelihood:                -155.29
# No. Observations:                  50   AIC:                             314.6
# Df Residuals:                      48   BIC:                             318.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               19.1242      0.914     20.920      0.000      17.286      20.962
# restaurant count     0.0036      0.005      0.788      0.435      -0.006       0.013
# ==============================================================================
# Omnibus:                        1.415   Durbin-Watson:                   1.415
# Prob(Omnibus):                  0.493   Jarque-Bera (JB):                1.418
# Skew:                           0.355   Prob(JB):                        0.492
# Kurtosis:                       2.581   Cond. No.                         236.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Model Analysis - Yelp:
#
# * pvalue of 0.434 indicates there is not a statistically significant relationship between the the number of restaurants to effectively predict the # of stalls available
# * a negative adjusted r-squared value of -0.008 indicates that this model explains no patterns  in the data.
# * Despite finding the original bug causing only 8 data points in previous analysis, It's clear that even with additional data points, there is no clear relationship between the count of restaurants and the number of city bikes stalls (See Scatter plots created in Joining Data).

# %% [markdown]
# ## Stretch

# %% [markdown]
# How can you turn the regression model into a classification model?

# %% [markdown]
# # trash

# %% [markdown]
# Build a regression model.

# %%
# imports
import requests
from IPython.display import JSON 
import pandas as pd
import os
import requests
import json
import matplotlib

# %%
import statsmodels.api as sm

# %% [markdown]
# ## Foursquare Data

# %%
# bring in data from part 3 
mtl_results_fsq = pd.read_csv('../data/mtl_results_fsq.csv')
mtl_results_fsq
# Out:
#      latitude  longitude  restaurant count  num stalls
# 0   45.617500 -73.606011                 6          11
# 1   45.516926 -73.564257                50          14
# 2   45.541549 -73.565012                41          11
# 3   45.506176 -73.711186                 9          19
# 4   45.512994 -73.682498                41          19
# 5   45.514734 -73.691449                42          15
# 6   45.522341 -73.721679                20          15
# 7   45.566869 -73.641017                10          15
# 8   45.548136 -73.624340                50          13
# 9   45.447916 -73.583819                 6          19
# 10  45.512933 -73.633890                15          23
# 11  45.429471 -73.593099                 4          23
# 12  45.523319 -73.520127                23          29
# 13  45.533682 -73.515261                34          15
# 14  45.537226 -73.495067                15          18
# 15  45.528410 -73.517166                27          10
# 16  45.467140 -73.542590                11          29
# 17  45.553219 -73.539782                48          22
# 18  45.564937 -73.555591                 7          23
# 19  45.505721 -73.629459                49          27
# 20  45.510163 -73.556637                50          32
# 21  45.526890 -73.572640                50          29
# 22  45.651406 -73.500413                16          15
# 23  45.606235 -73.628784                13          18
# 24  45.507144 -73.555119                50          15
# 25  45.506373 -73.524577                 6          19
# 26  45.521565 -73.535332                 3          21
# 27  45.457509 -73.639485                19          24
# 28  45.472561 -73.569989                50          17
# 29  45.605902 -73.534369                13          13
# 30  45.439145 -73.591737                 0          15
# 31  45.471882 -73.640022                28          22
# 32  45.553400 -73.662255                35          13
# 33  45.574147 -73.574621                30          21
# 34  45.597221 -73.562790                48          19
# 35  45.559842 -73.615447                21          33
# 36  45.554947 -73.555295                10          21
# 37  45.568330 -73.566663                 4          22
# 38  45.436568 -73.708370                 0          19
# 39  45.438056 -73.672739                19          19
# 40  45.456823 -73.546804                 2          14
# 41  45.489186 -73.571900                50          20
# 42  45.522525 -73.691440                18          22
# 43  45.508979 -73.698564                13          25
# 44  45.504038 -73.704443                13          23
# 45  45.490494 -73.638522                43          15
# 46  45.531944 -73.713605                18          12
# 47  45.480495 -73.577827                50          24
# 48  45.491226 -73.587630                50          22
# 49  45.593985 -73.637672                13          21

# %%
X = mtl_results_fsq['restaurant count']
y = pd.Series(mtl_results_fsq['num stalls'])

# %%
# check y and x values
X
# Out:
# 0      6
# 1     50
# 2     41
# 3      9
# 4     41
# 5     42
# 6     20
# 7     10
# 8     50
# 9      6
# 10    15
# 11     4
# 12    23
# 13    34
# 14    15
# 15    27
# 16    11
# 17    48
# 18     7
# 19    49
# 20    50
# 21    50
# 22    16
# 23    13
# 24    50
# 25     6
# 26     3
# 27    19
# 28    50
# 29    13
# 30     0
# 31    28
# 32    35
# 33    30
# 34    48
# 35    21
# 36    10
# 37     4
# 38     0
# 39    19
# 40     2
# 41    50
# 42    18
# 43    13
# 44    13
# 45    43
# 46    18
# 47    50
# 48    50
# 49    13
# Name: restaurant count, dtype: int64

# %%
y
# Out:
# 0     11
# 1     14
# 2     11
# 3     19
# 4     19
# 5     15
# 6     15
# 7     15
# 8     13
# 9     19
# 10    23
# 11    23
# 12    29
# 13    15
# 14    18
# 15    10
# 16    29
# 17    22
# 18    23
# 19    27
# 20    32
# 21    29
# 22    15
# 23    18
# 24    15
# 25    19
# 26    21
# 27    24
# 28    17
# 29    13
# 30    15
# 31    22
# 32    13
# 33    21
# 34    19
# 35    33
# 36    21
# 37    22
# 38    19
# 39    19
# 40    14
# 41    20
# 42    22
# 43    25
# 44    23
# 45    15
# 46    12
# 47    24
# 48    22
# 49    21
# Name: num stalls, dtype: int64

# %% [markdown]
# Provide model output and an interpretation of the results.

# %%
# make a regresssion to predict the num of restaurants based on the num of stalls available 
x = sm.add_constant(X) # adding a constant
lin_reg = sm.OLS(y,x)
print('x type:', type(x))
# Out:
# x type: <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Model Analysis - Foursquare:
#
# * very high p-value of 0.818 indicates there is not a statistically significant relationship between the the number of restaurants to effectively predict the # of stalls available
# * a negative adjusted r-square value of -0.020 indicates that this model does not effecitively explain any patterns in the data.
# * Despite finding the original bug causing only 8 data points in previous analysis, It's clear that even with additional data points, there is no clear relationship between the count of restaurants and the number of city bikes stalls (See Scatter plots created in Joining Data).

# %%
model = lin_reg.fit()
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             num stalls   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.020
# Method:                 Least Squares   F-statistic:                   0.05346
# Date:                Fri, 21 Apr 2023   Prob (F-statistic):              0.818
# Time:                        16:00:07   Log-Likelihood:                -155.59
# No. Observations:                  50   AIC:                             315.2
# Df Residuals:                      48   BIC:                             319.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               19.2420      1.364     14.107      0.000      16.500      21.984
# restaurant count     0.0104      0.045      0.231      0.818      -0.080       0.101
# ==============================================================================
# Omnibus:                        1.790   Durbin-Watson:                   1.418
# Prob(Omnibus):                  0.409   Jarque-Bera (JB):                1.688
# Skew:                           0.426   Prob(JB):                        0.430
# Kurtosis:                       2.711   Cond. No.                         52.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Yelp Data

# %%
mtl_results_yelp = pd.read_csv('../data/mtl_results_yelp.csv')
mtl_results_yelp
# Out:
#      latitude  longitude  restaurant count  num stalls
# 0   45.617500 -73.606011                18          11
# 1   45.516926 -73.564257               602          14
# 2   45.541549 -73.565012               100          11
# 3   45.506176 -73.711186                29          19
# 4   45.512994 -73.682498                89          19
# 5   45.514734 -73.691449                89          15
# 6   45.522341 -73.721679                27          15
# 7   45.566869 -73.641017                31          15
# 8   45.548136 -73.624340               150          13
# 9   45.447916 -73.583819                31          19
# 10  45.512933 -73.633890                23          23
# 11  45.429471 -73.593099                 8          23
# 12  45.523319 -73.520127                32          29
# 13  45.533682 -73.515261                58          15
# 14  45.537226 -73.495067                29          18
# 15  45.528410 -73.517166                50          10
# 16  45.467140 -73.542590                18          29
# 17  45.553219 -73.539782                82          22
# 18  45.564937 -73.555591                12          23
# 19  45.505721 -73.629459                84          27
# 20  45.510163 -73.556637               711          32
# 21  45.526890 -73.572640               360          29
# 22  45.651406 -73.500413                28          15
# 23  45.606235 -73.628784                27          18
# 24  45.507144 -73.555119               705          15
# 25  45.506373 -73.524577                14          19
# 26  45.521565 -73.535332                 6          21
# 27  45.457509 -73.639485                17          24
# 28  45.472561 -73.569989               108          17
# 29  45.605902 -73.534369                20          13
# 30  45.439145 -73.591737                 4          15
# 31  45.471882 -73.640022                33          22
# 32  45.553400 -73.662255                70          13
# 33  45.574147 -73.574621                41          21
# 34  45.597221 -73.562790                61          19
# 35  45.559842 -73.615447                40          33
# 36  45.554947 -73.555295                35          21
# 37  45.568330 -73.566663                16          22
# 38  45.436568 -73.708370                 0          19
# 39  45.438056 -73.672739                29          19
# 40  45.456823 -73.546804                 4          14
# 41  45.489186 -73.571900               452          20
# 42  45.522525 -73.691440                52          22
# 43  45.508979 -73.698564                22          25
# 44  45.504038 -73.704443                39          23
# 45  45.490494 -73.638522               141          15
# 46  45.531944 -73.713605                23          12
# 47  45.480495 -73.577827               200          24
# 48  45.491226 -73.587630               386          22
# 49  45.593985 -73.637672                36          21

# %%
X = mtl_results_yelp['restaurant count']
y = pd.Series(mtl_results_yelp['num stalls'])

# %%
# check y and x values
X
# Out:
# 0      18
# 1     602
# 2     100
# 3      29
# 4      89
# 5      89
# 6      27
# 7      31
# 8     150
# 9      31
# 10     23
# 11      8
# 12     32
# 13     58
# 14     29
# 15     50
# 16     18
# 17     82
# 18     12
# 19     84
# 20    711
# 21    360
# 22     28
# 23     27
# 24    705
# 25     14
# 26      6
# 27     17
# 28    108
# 29     20
# 30      4
# 31     33
# 32     70
# 33     41
# 34     61
# 35     40
# 36     35
# 37     16
# 38      0
# 39     29
# 40      4
# 41    452
# 42     52
# 43     22
# 44     39
# 45    141
# 46     23
# 47    200
# 48    386
# 49     36
# Name: restaurant count, dtype: int64

# %%
y
# Out:
# 0     11
# 1     14
# 2     11
# 3     19
# 4     19
# 5     15
# 6     15
# 7     15
# 8     13
# 9     19
# 10    23
# 11    23
# 12    29
# 13    15
# 14    18
# 15    10
# 16    29
# 17    22
# 18    23
# 19    27
# 20    32
# 21    29
# 22    15
# 23    18
# 24    15
# 25    19
# 26    21
# 27    24
# 28    17
# 29    13
# 30    15
# 31    22
# 32    13
# 33    21
# 34    19
# 35    33
# 36    21
# 37    22
# 38    19
# 39    19
# 40    14
# 41    20
# 42    22
# 43    25
# 44    23
# 45    15
# 46    12
# 47    24
# 48    22
# 49    21
# Name: num stalls, dtype: int64

# %%
# make a regresssion to predict the num of restaurants based on the num of stalls available 
x = sm.add_constant(X) # adding a constant
lin_reg = sm.OLS(y,x)
print('x type:', type(x))
# Out:
# x type: <class 'pandas.core.frame.DataFrame'>

# %%
model = lin_reg.fit()
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             num stalls   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.6206
# Date:                Fri, 21 Apr 2023   Prob (F-statistic):              0.435
# Time:                        16:00:39   Log-Likelihood:                -155.29
# No. Observations:                  50   AIC:                             314.6
# Df Residuals:                      48   BIC:                             318.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               19.1242      0.914     20.920      0.000      17.286      20.962
# restaurant count     0.0036      0.005      0.788      0.435      -0.006       0.013
# ==============================================================================
# Omnibus:                        1.415   Durbin-Watson:                   1.415
# Prob(Omnibus):                  0.493   Jarque-Bera (JB):                1.418
# Skew:                           0.355   Prob(JB):                        0.492
# Kurtosis:                       2.581   Cond. No.                         236.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Model Analysis - Yelp:
#
# * pvalue of 0.435 indicates there is not a statistically significant relationship between the the number of restaurants to effectively predict the # of stalls available
# * a negative adjusted r-squared value of -0.008 indicates that this model explains no patterns  in the data.
# * Despite finding the original bug causing only 8 data points in previous analysis, It's clear that even with additional data points, there is no clear relationship between the count of restaurants and the number of city bikes stalls (See Scatter plots created in Joining Data).

# %% [markdown]
# ## Stretch

# %% [markdown]
# How can you turn the regression model into a classification model?

# %% [markdown]
# ## the trash's trash

# %% [markdown]
# Build a regression model.

# %%
# imports
import requests
from IPython.display import JSON 
import pandas as pd
import os
import requests
import json
import matplotlib

# %%
import statsmodels.api as sm

# %% [markdown]
# ## Foursquare Data

# %%
# bring in data from part 3 
mtl_results = pd.read_csv('../data/mtl_results.csv')
mtl_results

# %%
X = mtl_results['restaurant count']
y = pd.Series(mtl_results['num stalls'])

# %%
# check y and x values
X

# %%
y

# %% [markdown]
# Provide model output and an interpretation of the results.

# %%
# make a regresssion to predict the num of restaurants based on the num of stalls available 
x = sm.add_constant(X) # adding a constant
lin_reg = sm.OLS(y,x)
print('x type:', type(x))

# %% [markdown]
# ### Model Analysis - Foursquare:
#
# * very high p-value of 0.891 indicates there is not a statistically significant relationship between the the number of restaurants to effectively predict the # of stalls available
# * very small r-square value of 0.003 indicates that this model explains less than 0.3% of the patterns in the data.
# * it's most likely that the low number of available data points (there are only 8 city bikes stations in montreal) is contributing to the lack of 'goodness'for the model
# * conclusion: not a strong model. Need to either look at other variables, or increase the # of stations. Even with the maximum results from foursquare.
#    - figures provided in 'joining_data" support this claim.

# %%
model = lin_reg.fit()
print_model = model.summary()
print(print_model)

# %% [markdown]
# ## Yelp Data

# %%
mtl_results_yelp = pd.read_csv('../data/mtl_results_yelp_clean.csv')
mtl_results_yelp

# %%
X = mtl_results_yelp['restaurant count']
y = pd.Series(mtl_results_yelp['num stalls'])

# %%
# check y and x values
X

# %%
y

# %%
# make a regresssion to predict the num of restaurants based on the num of stalls available 
x = sm.add_constant(X) # adding a constant
lin_reg = sm.OLS(y,x)
print('x type:', type(x))

# %%
model = lin_reg.fit()
print_model = model.summary()
print(print_model)

# %% [markdown]
# ### Model Analysis - Yelp:
#
# * pvalue of 0.703 there is not a statistically significant relationship between the the number of restaurants to effectively predict the # of stalls available
# * adjusted r-squared value of 0.032 indicates that this model can explain 3.2% of the patterns in the data.
# * it's most likely that the low number of available data points (there are only 8 city bikes stations in montreal) is contributing to the lack of 'goodness'for the model
# * conclusion: the model based on the yelp data is not a strong model and need to look at changing variables, increase the radius, etc. however, the yelp data model is a slightly stronger model than the model based on the foursquare data only.

# %% [markdown]
# ## Stretch

# %% [markdown]
# How can you turn the regression model into a classification model?
